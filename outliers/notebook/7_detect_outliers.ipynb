# %% [markdown]
# https://medium.com/data-reply-it-datatech/anomaly-detection-made-easy-with-pyod-960faf6da4e5

# %%
pip install pyod
# Out:
# Requirement already satisfied: pyod in c:\users\luan lima\appdata\local\programs\python\python310\lib\site-packages (1.1.0)
# Requirement already satisfied: joblib in c:\users\luan lima\appdata\local\programs\python\python310\lib\site-packages (from pyod) (1.3.2)
# Requirement already satisfied: matplotlib in c:\users\luan lima\appdata\local\programs\python\python310\lib\site-packages (from pyod) (3.7.2)
# Requirement already satisfied: numpy>=1.19 in c:\users\luan lima\appdata\local\programs\python\python310\lib\site-packages (from pyod) (1.25.1)
# Requirement already satisfied: numba>=0.51 in c:\users\luan lima\appdata\local\programs\python\python310\lib\site-packages (from pyod) (0.58.0)
# Requirement already satisfied: scipy>=1.5.1 in c:\users\luan lima\appdata\local\programs\python\python310\lib\site-packages (from pyod) (1.11.2)
# Requirement already satisfied: scikit_learn>=0.20.0 in c:\users\luan lima\appdata\local\programs\python\python310\lib\site-packages (from pyod) (1.3.0)
# Requirement already satisfied: six in c:\users\luan lima\appdata\roaming\python\python310\site-packages (from pyod) (1.16.0)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in c:\users\luan lima\appdata\local\programs\python\python310\lib\site-packages (from numba>=0.51->pyod) (0.41.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\luan lima\appdata\local\programs\python\python310\lib\site-packages (from scikit_learn>=0.20.0->pyod) (3.2.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\luan lima\appdata\roaming\python\python310\site-packages (from matplotlib->pyod) (23.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\luan lima\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->pyod) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\luan lima\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->pyod) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\luan lima\appdata\roaming\python\python310\site-packages (from matplotlib->pyod) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\luan lima\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->pyod) (4.42.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\luan lima\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->pyod) (10.0.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\luan lima\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->pyod) (1.4.5)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\luan lima\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->pyod) (3.0.9)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.2.2 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pyod
from pyod.models.knn import KNN

# %%
from pyod.utils.data import generate_data
from pyod.utils.data import generate_data
from pyod.utils.data import evaluate_print
from pyod.utils.example import visualize

# %%
contamination = 0.1  # percentage of outliers
n_train = 200  # number of training points
n_test = 100  # number of testing points

X_train, X_test, y_train, y_test = generate_data(n_train=n_train, n_test=n_test, contamination=contamination)

# %%
# train kNN detector
clf_name = 'KNN'
clf = KNN()
clf.fit(X_train)

# get the prediction labels and outlier scores of the training data
y_train_pred = clf.labels_  # binary labels (0: inliers, 1: outliers)
y_train_scores = clf.decision_scores_  # raw outlier scores

# get the prediction on the test data
y_test_pred = clf.predict(X_test)  # outlier labels (0 or 1)
y_test_scores = clf.decision_function(X_test)  # outlier scores

# it is possible to get the prediction confidence as well
y_test_pred, y_test_pred_confidence = clf.predict(X_test, return_confidence=True)  # outlier labels (0 or 1) and confidence in the range of [0,1]

# %%
from pyod.utils.data import evaluate_print
# evaluate and print the results
print("\nOn Training Data:")
evaluate_print(clf_name, y_train, y_train_scores)
print("\nOn Test Data:")
evaluate_print(clf_name, y_test, y_test_scores)
# Out:
# On Training Data:
# KNN ROC:1.0, precision @ rank n:1.0
#
# On Test Data:
# KNN ROC:1.0, precision @ rank n:1.0

# %%
visualize(clf_name, X_train, y_train, X_test, y_test, y_train_pred,
          y_test_pred, show_figure=True, save_figure=False)
